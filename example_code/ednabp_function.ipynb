# %% [markdown]
# ## Module `FastqProcessor`

# %% [markdown]
# ### Python API

# %%
from ednabp import FastqProcessor

FastqProcessor(
    input_path=INPUT_PATH,
    output_path=OUTPUT_PATH,
    db_path=DB_PATH,
    lineage_path=LINEAGE_PATH,
    n_cpu=20,
)

# %% [markdown]
# ### CLI

# %%
# !eDNAbp -h
#!eDNAbp -i INPUT_PATH -o OUTPUT_PATH -db DB_PATH -ln LINEAGE_PATH --n-cpu 20

# %% [markdown]
# ## Module `SampleData`

# %%
import importlib
import ednabp

importlib.reload(ednabp)

# %%
from ednabp import SampleData

CJ_data = SampleData()
CJ_data.unpickle_data(pickle_path="./edNA/test_on_data/CJ_test/CJ_data.pkl")

# %%
TI_data = SampleData()
TI_data.unpickle_data(pickle_path="./edNA/test_on_data/TI_test/TI_data.pkl")

# %%
CJ_data = SampleData()
CJ_data.import_data(
    dereplicate_dir="./edNA/test_on_data/CJ_test/dereplicate",
    denoise_dir="./edNA/test_on_data/CJ_test/denoise",
    assigntaxa_dir="./edNA/test_on_data/CJ_test/assigntaxa",
    sample_metadata_path="./edNA/test_on_data/CJ_test/metadata.csv",
    fishbase_db_path="./edNA/data/database/species.parquet",
    stock_db_path="./edNA/data/database/stocks.parquet",
)
# CJ_data.merge_data(OTHER_SAMPLEDATA_INST)
CJ_data.pickle_data(
    save_dir="./edNA/test_on_data/CJ_test",
    save_prefix="CJ_data",
    overwrite=True,
)

# %%
TI_data = SampleData()
TI_data.import_data(
    dereplicate_dir="./edNA/test_on_data/TI_test/dereplicate",
    denoise_dir="./edNA/test_on_data/TI_test/denoise",
    assigntaxa_dir="./edNA/test_on_data/TI_test/assigntaxa",
    sample_metadata_path="./edNA/test_on_data/TI_test/metadata.csv",
    fishbase_db_path="./edNA/data/database/species.parquet",
    stock_db_path="./edNA/data/database/stocks.parquet",
)
# TI_data.merge_data(OTHER_SAMPLEDATA_INST)
TI_data.pickle_data(
    save_dir="./edNA/test_on_data/TI_test",
    save_prefix="TI_data",
    overwrite=True,
)

# %%
TI_data.spc_info

# %% [markdown]
# ## Module `MitoData`

# %%
from ednabp import MitoData

mito_data = MitoData()
mito_data.import_data("./edNA/ednabp")

# %%
mito_data.spc_info

# %% [markdown]
# ## Module `DMAnalyser`

# %%
from ednabp import DMAnalyser

# dm_analyser = DMAnalyser(sampledata=CJ_data)
dm_analyser = DMAnalyser()

# %% [markdown]
# ### Function `write_abundance_table`

# %%
dm_analyser.write_abundance_table(
    save_dir="./edNA/test_on_data/CJ_test",
    taxa_level="species",
    process=None,  # "norm", "log",
    sample_id_list=None,
    overwrite=True,
)

# %% [markdown]
# ### Function `write_richness_table`

# %%
dm_analyser.write_richness_table(
    save_dir="./edNA/CJ_test",
    taxa_level="family",
    unit_level="species",
    sample_id_list=None,
)

# %% [markdown]
# ### Function `write_detectprob_table`

# %%
dm_analyser.write_detectprob_table(
    save_dir="./edNA/CJ_test", taxa_level="family"
)

# %% [markdown]
# ### Function `plot_barchart`

# %%
dm_analyser.plot_barchart(
    csv_path="./edNA/TI_test/species_raw_abundance.csv",
    taxa_column="species",
    metric_column="abundance",
    save_dir=None,
    overwrite=False,
)

# %%
dm_analyser.plot_barchart(
    csv_path="./edNA/TI_test/species_norm_abundance.csv",
    taxa_column="species",
    metric_column="abundance",
    save_dir=None,
    overwrite=False,
)

# %%
dm_analyser.plot_barchart(
    csv_path="./edNA/TI_test/family_species_richness.csv",
    taxa_column="family",
    metric_column="richness",
    save_dir=None,
    overwrite=False,
)

# %% [markdown]
# ### Function `plot_contour`

# %%
dm_analyser.plot_contour(
    csv_path="./edNA/TI_test/species_raw_abundance.csv",
    shp_path="./edNA/TI_test/gis/kueishan.shp",
    metric_column="abundance",
    save_dir=None,
    overwrite=False,
)

# %%
dm_analyser.plot_contour(
    csv_path="./edNA/TI_test/species_log_abundance.csv",
    shp_path="./edNA/TI_test/gis/kueishan.shp",
    metric_column="abundance",
    save_dir=None,
    overwrite=False,
)

# %%
dm_analyser.plot_contour(
    csv_path="./edNA/TI_test/family_species_richness.csv",
    shp_path="./edNA/TI_test/gis/kueishan.shp",
    metric_column="richness",
    save_dir=None,
    overwrite=False,
)

# %% [markdown]
# ### Function `plot_heatmap`

# %%
dm_analyser.plot_heatmap(
    csv_path="./edNA/test_on_data/CJ_test/family_species_richness.csv",
    values="richness",
    index="family",
    columns=["Date", "Site"],
)

# %%
dm_analyser.plot_heatmap(
    csv_path="./edNA/test_on_data/CJ_test/species_detectprob.csv",
    values="detect_prob",
    index="species",
    columns=["Date", "Site"],
)

# %% [markdown]
# ### Function `plot_rankcorr`

# %%
dm_analyser.plot_rankcorr(
    csv_path="./edNA/test_on_data/CJ_test/species_raw_abundance.csv",
    values="abundance",
    index="species",
    columns=["sample_id"],
    aggfunc="mean",
    rcorr="kendall",
    alpha=0.05,
    colorscale="tempo",
    save_dir="./edNA/test_on_data/CJ_test",
)

# %% [markdown]
# ### Function `plot_sankey`

# %%
dm_analyser.plot_sankey(
    csv_path="./edNA/test_on_data/CJ_test/species_raw_abundance.csv",
    values="abundance",
    categories=["Date", "Site", "Habitat"],
    aggfunc="sum",
    save_dir="./edNA/test_on_data/CJ_test",
)

# %% [markdown]
# # Module `SeqAnalyser`

# %%
import importlib
import ednabp

importlib.reload(ednabp)

# %%
from ednabp import SampleData

CJ_data = SampleData()
CJ_data.unpickle_data(pickle_path="./edNA/test_on_data/CJ_test/CJ_data.pkl")

# %%
from ednabp import SeqAnalyser

seq_analyser = SeqAnalyser(sampledata=CJ_data)

# %%
import numpy as np

family_list = []
for sample_id in CJ_data.sample_id_list:
    family_list.extend(
        [
            lv["family"]
            for lv in CJ_data.sample_data[sample_id].hap2level.values()
        ]
    )
family_list = np.unique(family_list)

# %%
seq_analyser.write_umap_index(
    taxa_list=family_list,
    taxa_level="family",
    unit_level="species",
    save_dir="./edNA/test_on_data/CJ_test",
    neighbors=15,
    min_dist=0.1,
    random_state=None,
    calc_dist=False,
    sample_id_list=None,
)

# %%
seq_analyser.plot_umap(
    index_path="./edNA/test_on_data/CJ_test/umap_index.tsv",
    n_unit_threshold=15,
    category="all",
    save_dir="./edNA/test_on_data/CJ_test/",
    cmap="Spectral",
    show_legend=True,
)
